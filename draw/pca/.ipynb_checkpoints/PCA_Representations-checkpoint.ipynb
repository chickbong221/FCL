# %%
import os
import torch
from torch import nn
import numpy as np
import copy
import gc
from torch.utils.data import TensorDataset, DataLoader
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

device = "cuda"
current_dir = os.getcwd()
print("Current Directory:", current_dir)
# Out:
# Current Directory: /home/skydvn/Documents/git/ContinualLearning/FCL/draw/pca

# %%
def load_full_test_data(datadir, dataset="IMAGENET1k", train_images_per_class=5000, test_images_per_class=1000, concat_every=5):
    if dataset == "CIFAR100":
        classes = list(range(100))
    elif dataset == "CIFAR10":
        classes = list(range(10))
    elif dataset == "IMAGENET1k":
        classes = list(range(1000))
    else:
        raise NotImplementedError("Not supported dataset")

    x_test_all = None
    y_test_all = None

    x_test_list, y_test_list = [], []

    for i, _class in enumerate(classes):
        print(f"Loading data full for class {_class}...")
        data_file = datadir + str(_class) + '.npy'
        data = np.load(data_file)  

        new_x_test = data[train_images_per_class:]  
        new_y_test = np.full((test_images_per_class,), _class, dtype=np.int64)

        x_test_list.append(new_x_test)
        y_test_list.append(new_y_test)

        # Mỗi concat_every class thì concat để giảm bộ nhớ
        if (i + 1) % concat_every == 0 or (i + 1) == len(classes):

            if x_test_all is None:
                x_test_all = np.concatenate(x_test_list, axis=0)
                y_test_all = np.concatenate(y_test_list, axis=0)
            else:
                x_test_all = np.concatenate([x_test_all] + x_test_list, axis=0)
                y_test_all = np.concatenate([y_test_all] + y_test_list, axis=0)

            # Giải phóng bộ nhớ
            x_test_list.clear()
            y_test_list.clear()
            gc.collect()

    # Convert sang tensor
    x_test_tensor = torch.tensor(x_test_all, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test_all, dtype=torch.long)

    print(f"Loaded {len(x_test_tensor)} test images and {len(y_test_tensor)} test labels.")
    return x_test_tensor, y_test_tensor

# %%
# TODO Model Initialization
class FedAvgCNN(nn.Module):
    def __init__(self, in_features=1, num_classes=10, dim=1024):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_features,
                        32,
                        kernel_size=5,
                        padding=0,
                        stride=1,
                        bias=True),
            nn.ReLU(inplace=True), 
            nn.MaxPool2d(kernel_size=(2, 2))
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(32,
                        64,
                        kernel_size=5,
                        padding=0,
                        stride=1,
                        bias=True),
            nn.ReLU(inplace=True), 
            nn.MaxPool2d(kernel_size=(2, 2))
        )
        self.fc1 = nn.Sequential(
            nn.Linear(dim, 512), 
            nn.ReLU(inplace=True)
        )
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = torch.flatten(out, 1)
        out = self.fc1(out)
        out = self.fc(out)
        return out

class BaseHeadSplit(nn.Module):
    def __init__(self, base, head):
        super(BaseHeadSplit, self).__init__()

        self.base = base
        self.head = head
        
    def forward(self, x):
        out = self.base(x)
        out = self.head(out)

        return out

    def get_proto(self, x):
        hidden = self.base(x)
        out    = self.head(hidden)

        return hidden, out


model = FedAvgCNN(in_features=3, num_classes=10, dim=1600).to(device)
head = copy.deepcopy(model.fc)
model.fc = nn.Identity()
model = BaseHeadSplit(model, head)

# %%
x_test_tensor, y_test_tensor = load_full_test_data(
    datadir='/home/skydvn/Documents/git/ContinualLearning/FCL/dataset/cifar10-classes/',
    dataset="CIFAR10",
    train_images_per_class=5000,
    test_images_per_class=1000
)

# Wrap in a dataset and dataloader
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
# Out:
# Loading data full for class 0...
# Loading data full for class 1...
# Loading data full for class 2...
# Loading data full for class 3...
# Loading data full for class 4...
# Loading data full for class 5...
# Loading data full for class 6...
# Loading data full for class 7...
# Loading data full for class 8...
# Loading data full for class 9...
# Loaded 10000 test images and 10000 test labels.

# %%
# Load model
checkpoint = torch.load("/home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedAvg_2025-05-14_22-10-37/local/task_4_round_23.pth", map_location=device)
model.load_state_dict(checkpoint)

# Collect all embeddings and labels from the test set
def get_embeddings(model, test_loader, device):
    model.eval()
    embeddings = []
    labels = []
    
    with torch.no_grad():
        for images, targets in test_loader:
            images = images.to(device)
            proto, output = model.get_proto(images)
            embeddings.append(proto.cpu())
            labels.append(targets.cpu())

    embeddings = torch.cat(embeddings, dim=0).numpy()
    labels = torch.cat(labels, dim=0).numpy()
    return embeddings, labels

# Perform PCA and plot
def plot_pca(embeddings, labels, n_components=2):
    pca = PCA(n_components=n_components)
    reduced = pca.fit_transform(embeddings)

    plt.figure(figsize=(8, 6))
    for label in np.unique(labels):
        idx = labels == label
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=f"Class {label}", alpha=0.6)
    
    plt.title("PCA of Embeddings")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.legend()
    plt.grid(True)
    plt.show()


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)

embeddings, labels = get_embeddings(model, test_loader, device)
plot_pca(embeddings, labels)

# %%
import re

def plot_pca_and_save(embeddings, labels, save_path, n_components=2):
    pca = PCA(n_components=n_components)
    reduced = pca.fit_transform(embeddings)
    
    plt.figure(figsize=(8, 6))
    for label in np.unique(labels):
        idx = labels == label
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=f"Class {label}", alpha=0.6)

    plt.title("PCA of Embeddings")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.legend()
    plt.grid(True)
    
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    plt.savefig(save_path)
    plt.close()

# === Define paths ===
# base_input_dir = "/home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08"
# base_output_dir = "/home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08"

base_input_dir = "/home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08"
base_output_dir = "/home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08"

# === Loop through hierarchical folders ===
for mode in ['global', 'local']:
    mode_input_dir = os.path.join(base_input_dir, mode)
    mode_output_dir = os.path.join(base_output_dir, mode)

    for root, dirs, files in os.walk(mode_input_dir):
        for file in files:
            if not file.endswith('.pth'):
                continue

            match = re.match(r'task_(\d+)_round_(\d+)\.pth', file)
            if not match:
                print(f"Skipping file with unexpected format: {file}")
                continue

            task_id, round_id = match.groups()
            input_path = os.path.join(root, file)
            output_path = os.path.join(mode_output_dir, f"task_{task_id}", f"round_{round_id}.png")

            print(f"Processing {input_path} -> {output_path}")

            # Load model
            model = FedAvgCNN(in_features=3, num_classes=10, dim=1600).to(device)
            head = copy.deepcopy(model.fc)
            model.fc = nn.Identity()
            model = BaseHeadSplit(model, head)
            checkpoint = torch.load(input_path, map_location=device)
            state_dict = checkpoint.get('model_state_dict', checkpoint)
            model.load_state_dict(state_dict)
            model.to(device)

            # Extract embeddings and plot
            embeddings, labels = get_embeddings(model, test_loader, device)
            plot_pca_and_save(embeddings, labels, output_path)
# Out:
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_9_round_7.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_9/round_7.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_24_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_24/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_11_round_7.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_11/round_7.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_8_round_6.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_8/round_6.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_21_round_14.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_21/round_14.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_12_round_16.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_12/round_16.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_16_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_16/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_12_round_24.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_12/round_24.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_4_round_17.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_4/round_17.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_10_round_13.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_10/round_13.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_9_round_9.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_9/round_9.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_16_round_13.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_16/round_13.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_10.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_10.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_22_round_17.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_22/round_17.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_23.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_23.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_17_round_24.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_17/round_24.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_12_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_12/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_3_round_11.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_3/round_11.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_9.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_9.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_15_round_19.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_15/round_19.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_5_round_22.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_5/round_22.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_5_round_4.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_5/round_4.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_3_round_14.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_3/round_14.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_15_round_12.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_15/round_12.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_0.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_0.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_10_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_10/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_24_round_5.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_24/round_5.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_14_round_14.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_14/round_14.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_10_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_10/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_14_round_18.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_14/round_18.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_23_round_7.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_23/round_7.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_5.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_5.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_3_round_12.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_3/round_12.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_15_round_6.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_15/round_6.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_0_round_20.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_0/round_20.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_23_round_23.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_23/round_23.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_3_round_19.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_3/round_19.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_7_round_10.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_7/round_10.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_23_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_23/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_8_round_13.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_8/round_13.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_20_round_9.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_20/round_9.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_7_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_7/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_1_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_1/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_7_round_19.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_7/round_19.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_13_round_2.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_13/round_2.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_1_round_18.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_1/round_18.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_4_round_10.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_4/round_10.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_0_round_9.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_0/round_9.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_17_round_21.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_17/round_21.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_24_round_24.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_24/round_24.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_6_round_0.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_6/round_0.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_17_round_4.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_17/round_4.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_4_round_18.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_4/round_18.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_13_round_3.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_13/round_3.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_23_round_12.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_23/round_12.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_12_round_6.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_12/round_6.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_22_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_22/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_13_round_22.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_13/round_22.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_23_round_22.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_23/round_22.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_10_round_14.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_10/round_14.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_6_round_19.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_6/round_19.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_13_round_11.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_13/round_11.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_20_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_20/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_22_round_16.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_22/round_16.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_5_round_18.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_5/round_18.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_8_round_21.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_8/round_21.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_15_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_15/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_21_round_16.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_21/round_16.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_2_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_2/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_16_round_1.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_16/round_1.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_3_round_16.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_3/round_16.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_24_round_0.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_24/round_0.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_2_round_4.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_2/round_4.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_17_round_23.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_17/round_23.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_18_round_18.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_18/round_18.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_13_round_15.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_13/round_15.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_11_round_21.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_11/round_21.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_7_round_8.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_7/round_8.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task_21_round_13.pth -> /home/skydvn/Documents/git/ContinualLearning/FCL/Proto/FedSTGM_2025-05-15_18-51-08/global/task_21/round_13.png
# Processing /home/skydvn/Documents/git/ContinualLearning/FCL/pca_eval/FedSTGM/FedSTGM_2025-05-15_18-51-08/global/task